# %%
# Imports

import os
import re
import langid

os.environ["TRANSFORMERS_CACHE"] = "/hpc/home/bfa6/work/llms/.cache"
os.environ["HF_HOME"] = "/hpc/home/bfa6/work/llms/.cache"

import time
import json

from unsloth import FastLanguageModel
import torch
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from dotenv import dotenv_values
from tqdm import tqdm
import asyncio
from tqdm.asyncio import tqdm_asyncio
from google import genai
import random
from datasets import Dataset
from trl import SFTTrainer, SFTConfig
from transformers import TextStreamer
import vllm
import nltk
from bert_score import score as bert_score
from collections import Counter

config = dotenv_values("../.env")

# %% [markdown]
# # Load the model

# %%
max_seq_length = 2048 # Can increase for longer reasoning traces
lora_rank = 8 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-4B-Instruct-2507",
    cache_dir="/hpc/home/bfa6/work/llms/.cache",
    max_seq_length = max_seq_length,
    load_in_4bit = False, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
    force_download=True
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha = lora_rank*2, # *2 speeds up training
    use_gradient_checkpointing = "unsloth", # Reduces memory usage
    random_state = 3407,
)
# Out:
# INFO 11-20 20:48:12 [vllm_utils.py:700] Unsloth: Patching vLLM v1 graph capture
# ==((====))==  Unsloth 2025.11.2: Fast Qwen3 patching. Transformers: 4.56.2. vLLM: 0.11.0.
#    \\   /|    NVIDIA RTX 6000 Ada Generation. Num GPUs = 1. Max memory: 47.372 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/Qwen3-4B-Instruct-2507 with actual GPU utilization = 59.41%
# Unsloth: Your GPU has CUDA compute capability 8.9 with VRAM = 47.37 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 2048. Num Sequences = 288.
# Unsloth: vLLM's KV Cache can use up to 21.28 GB. Also swap space = 6 GB.
# Unsloth: Not an error, but `device` is not supported in vLLM. Skipping.
# INFO 11-20 20:48:15 [utils.py:233] non-default args: {'dtype': torch.bfloat16, 'seed': 0, 'max_model_len': 2048, 'enable_prefix_caching': True, 'swap_space': 6, 'gpu_memory_utilization': 0.5941472125626335, 'max_num_batched_tokens': 2048, 'max_num_seqs': 288, 'max_logprobs': 0, 'disable_log_stats': True, 'enable_lora': True, 'max_lora_rank': 8, 'enable_chunked_prefill': True, 'compilation_config': {"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":null,"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":25,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":null,"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":null,"local_cache_dir":null}, 'model': 'unsloth/Qwen3-4B-Instruct-2507'}
# INFO 11-20 20:48:15 [model.py:547] Resolved architecture: Qwen3ForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 11-20 20:48:15 [model.py:1510] Using max model len 2048
# INFO 11-20 20:48:18 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=2048.
# WARNING 11-20 20:48:18 [lora.py:92] `lora_extra_vocab_size` is deprecated and will be removed in v0.12.0. Additional vocabulary support for LoRA adapters is being phased out.
# INFO 11-20 20:48:19 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='unsloth/Qwen3-4B-Instruct-2507', speculative_config=None, tokenizer='unsloth/Qwen3-4B-Instruct-2507', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=2048, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/Qwen3-4B-Instruct-2507, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention","vllm.sparse_attn_indexer"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":25,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# INFO 11-20 20:48:19 [parallel_state.py:1208] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# WARNING 11-20 20:48:19 [topk_topp_sampler.py:66] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# INFO 11-20 20:48:20 [gpu_model_runner.py:2602] Starting to load model unsloth/Qwen3-4B-Instruct-2507...
# INFO 11-20 20:48:20 [gpu_model_runner.py:2634] Loading model from scratch...
# INFO 11-20 20:48:20 [cuda.py:366] Using Flash Attention backend on V1 engine.
# INFO 11-20 20:48:21 [weight_utils.py:392] Using model weights format ['*.safetensors']
# Loading safetensors checkpoint shards:   0% Completed | 0/2 [00:00<?, ?it/s]
# INFO 11-20 20:48:34 [default_loader.py:267] Loading weights took 13.51 seconds
# INFO 11-20 20:48:34 [punica_selector.py:19] Using PunicaWrapperGPU.
# INFO 11-20 20:48:35 [gpu_model_runner.py:2653] Model loading took 7.5958 GiB and 14.452287 seconds
# INFO 11-20 20:48:47 [backends.py:548] Using cache directory: /hpc/home/bfa6/.cache/vllm/torch_compile_cache/8b07e84999/rank_0_0/backbone for vLLM's torch.compile
# INFO 11-20 20:48:48 [backends.py:559] Dynamo bytecode transform time: 11.21 s
# Unsloth: Compiling kernels: 100%|██████████| 7/7 [00:02<00:00,  3.36it/s, triton_poi_fused_view_6]
# INFO 11-20 20:48:55 [backends.py:197] Cache the graph for dynamic shape for later use
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:02<00:00,  4.38it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 97.94it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 112.25it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 78.54it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 117.94it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 123.82it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 86.14it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 102.67it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 124.54it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 88.75it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 92.15it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 63.24it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 83.64it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 72.39it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 83.84it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 90.16it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 82.99it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 92.57it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 82.30it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 90.76it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 94.67it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 90.90it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 72.55it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 110.04it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 112.77it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 114.81it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 113.43it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 120.02it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 102.70it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 130.83it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 126.83it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 114.24it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 98.76it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 114.37it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 115.69it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 10.94it/s, triton_red_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# INFO 11-20 20:49:48 [backends.py:218] Compiling a graph for dynamic shape takes 58.70 s
# INFO 11-20 20:50:27 [monitor.py:34] torch.compile takes 69.91 s in total
# INFO 11-20 20:50:29 [gpu_worker.py:298] Available KV cache memory: 18.95 GiB
# INFO 11-20 20:50:29 [kv_cache_utils.py:1087] GPU KV cache size: 138,000 tokens
# INFO 11-20 20:50:29 [kv_cache_utils.py:1091] Maximum concurrency for 2,048 tokens per request: 67.38x
# INFO 11-20 20:50:29 [vllm_utils.py:705] Unsloth: Running patched vLLM v1 `capture_model`.
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 67/67 [00:24<00:00,  2.74it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 39/39 [00:05<00:00,  6.66it/s]
# INFO 11-20 20:51:00 [gpu_model_runner.py:3480] Graph capturing finished in 30 secs, took 1.25 GiB
# INFO 11-20 20:51:00 [vllm_utils.py:712] Unsloth: Patched vLLM v1 graph capture finished in 30 secs.
# INFO 11-20 20:51:01 [core.py:210] init engine (profile, create kv cache, warmup model) took 145.91 seconds
# INFO 11-20 20:51:02 [llm.py:306] Supported_tasks: ('generate',)
# Unsloth: Just some info: will skip parsing ['layer_norm1', 'input_layernorm', 'layer_norm2', 'norm2', 'norm1', 'attention_norm', 'q_norm', 'ffn_norm', 'k_norm', 'post_feedforward_layernorm', 'norm', 'post_layernorm', 'pre_feedforward_layernorm', 'post_attention_layernorm']
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Performing substitution for additional_keys=set()
# Unsloth: Just some info: will skip parsing ['layer_norm1', 'input_layernorm', 'cross_attn_input_layernorm', 'layer_norm2', 'norm2', 'norm1', 'attention_norm', 'q_norm', 'ffn_norm', 'k_norm', 'post_feedforward_layernorm', 'norm', 'post_layernorm', 'cross_attn_post_attention_layernorm', 'pre_feedforward_layernorm', 'post_attention_layernorm']
# Unsloth 2025.11.2 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %% [markdown]
# # Create a chat template

# %%
system_prompt = (
    "Your goal is to compress the information from the user in as few tokens as necessary and output the compressed version.\n"
    "Mix different languages to compress the information. Examples langauges to include: Chinese (Simplified), Chinese (Traditional), Japanese, Korean, Thai, Vietnamese, German, Turkish, Finnish, Hungarian, Russian, Polish, Arabic, Hebrew\n"
    "Do NOT produce internal chain-of-thought or step-by-step reasoning.\n"
    "Start immediately with the compressed content (no extra preface)."
)
system_prompt
# Out:
# 'Your goal is to compress the information from the user in as few tokens as necessary and output the compressed version.\nMix different languages to compress the information. Examples langauges to include: Chinese (Simplified), Chinese (Traditional), Japanese, Korean, Thai, Vietnamese, German, Turkish, Finnish, Hungarian, Russian, Polish, Arabic, Hebrew\nDo NOT produce internal chain-of-thought or step-by-step reasoning.\nStart immediately with the compressed content (no extra preface).'

# %%
# chat_template = \
#     "{% if messages[0]['role'] == 'system' %}"\
#         "{{ messages[0]['content'] + eos_token }}"\
#         "{% set loop_messages = messages[1:] %}"\
#     "{% else %}"\
#         "{{ '{system_prompt}' + eos_token }}"\
#         "{% set loop_messages = messages %}"\
#     "{% endif %}"\
#     "{% for message in loop_messages %}"\
#         "{% if message['role'] == 'user' %}"\
#             "{{ '<|user|>\\n' + message['content'] + eos_token }}"\
#         "{% elif message['role'] == 'assistant' %}"\
#             "{{ '<|assistant|>\\n' + message['content'] + eos_token }}"\
#         "{% endif %}"\
#     "{% endfor %}"

# # Replace with out specific template:
# chat_template = chat_template\
#     .replace("'{system_prompt}'",   f"'{system_prompt}'")

# from unsloth.chat_templates import qwen3_template
# tokenizer.chat_template = qwen3_template

tokenizer.chat_template
# Out:
# '{%- if tools %}\n    {{- \'<|im_start|>system\\n\' }}\n    {%- if messages[0].role == \'system\' %}\n        {{- messages[0].content + \'\\n\\n\' }}\n    {%- endif %}\n    {{- "# Tools\\n\\nYou may call one or more functions to assist with the user query.\\n\\nYou are provided with function signatures within <tools></tools> XML tags:\\n<tools>" }}\n    {%- for tool in tools %}\n        {{- "\\n" }}\n        {{- tool | tojson }}\n    {%- endfor %}\n    {{- "\\n</tools>\\n\\nFor each function call, return a json object with function name and arguments within <tool_call></tool_call> XML tags:\\n<tool_call>\\n{\\"name\\": <function-name>, \\"arguments\\": <args-json-object>}\\n</tool_call><|im_end|>\\n" }}\n{%- else %}\n    {%- if messages[0].role == \'system\' %}\n        {{- \'<|im_start|>system\\n\' + messages[0].content + \'<|im_end|>\\n\' }}\n    {%- endif %}\n{%- endif %}\n{%- set ns = namespace(multi_step_tool=true, last_query_index=messages|length - 1) %}\n{%- for message in messages[::-1] %}\n    {%- set index = (messages|length - 1) - loop.index0 %}\n    {%- if ns.multi_step_tool and message.role == "user" and message.content is string and not(message.content.startswith(\'<tool_response>\') and message.content.endswith(\'</tool_response>\')) %}\n        {%- set ns.multi_step_tool = false %}\n        {%- set ns.last_query_index = index %}\n    {%- endif %}\n{%- endfor %}\n{%- for message in messages %}\n    {%- if message.content is string %}\n        {%- set content = message.content %}\n    {%- else %}\n        {%- set content = \'\' %}\n    {%- endif %}\n    {%- if (message.role == "user") or (message.role == "system" and not loop.first) %}\n        {{- \'<|im_start|>\' + message.role + \'\\n\' + content + \'<|im_end|>\' + \'\\n\' }}\n    {%- elif message.role == "assistant" %}\n        {%- set reasoning_content = \'\' %}\n        {%- if message.reasoning_content is string %}\n            {%- set reasoning_content = message.reasoning_content %}\n        {%- else %}\n            {%- if \'</think>\' in content %}\n                {%- set reasoning_content = content.split(\'</think>\')[0].rstrip(\'\\n\').split(\'<think>\')[-1].lstrip(\'\\n\') %}\n                {%- set content = content.split(\'</think>\')[-1].lstrip(\'\\n\') %}\n            {%- endif %}\n        {%- endif %}\n        {%- if loop.index0 > ns.last_query_index %}\n            {%- if loop.last or (not loop.last and reasoning_content) %}\n                {{- \'<|im_start|>\' + message.role + \'\\n<think>\\n\' + reasoning_content.strip(\'\\n\') + \'\\n</think>\\n\\n\' + content.lstrip(\'\\n\') }}\n            {%- else %}\n                {{- \'<|im_start|>\' + message.role + \'\\n\' + content }}\n            {%- endif %}\n        {%- else %}\n            {{- \'<|im_start|>\' + message.role + \'\\n\' + content }}\n        {%- endif %}\n        {%- if message.tool_calls %}\n            {%- for tool_call in message.tool_calls %}\n                {%- if (loop.first and content) or (not loop.first) %}\n                    {{- \'\\n\' }}\n                {%- endif %}\n                {%- if tool_call.function %}\n                    {%- set tool_call = tool_call.function %}\n                {%- endif %}\n                {{- \'<tool_call>\\n{"name": "\' }}\n                {{- tool_call.name }}\n                {{- \'", "arguments": \' }}\n                {%- if tool_call.arguments is string %}\n                    {{- tool_call.arguments }}\n                {%- else %}\n                    {{- tool_call.arguments | tojson }}\n                {%- endif %}\n                {{- \'}\\n</tool_call>\' }}\n            {%- endfor %}\n        {%- endif %}\n        {{- \'<|im_end|>\\n\' }}\n    {%- elif message.role == "tool" %}\n        {%- if loop.first or (messages[loop.index0 - 1].role != "tool") %}\n            {{- \'<|im_start|>user\' }}\n        {%- endif %}\n        {{- \'\\n<tool_response>\\n\' }}\n        {{- content }}\n        {{- \'\\n</tool_response>\' }}\n    ...

# %% [markdown]
# # Prepare dataset

# %%
# load dataset
with open("/hpc/home/bfa6/work/github/yapper/dataset/chunks.json", "r") as f:
    dataset =  json.load(f)


len(dataset)
# Out:
# 18914

# %%
def clean_whitespace(text: str) -> str:
    # Collapse multiple spaces/tabs into a single space
    text = re.sub(r'[ \t]+', ' ', text)
    # Collapse multiple newlines into a single newline
    text = re.sub(r'\n+', '\n', text)
    # Strip leading/trailing whitespace
    return text.strip()


for data in tqdm(dataset):
    data["chunk"] = clean_whitespace(data["chunk"])
# Out:
# 100%|██████████| 18914/18914 [00:03<00:00, 5655.29it/s]

# %%
def get_text_len(text: str):
    inp = [{"role":"system", "content": system_prompt}, {"role":"user", "content": text}]
    text = tokenizer.apply_chat_template(
        inp,
        tokenize = False,
        add_generation_prompt=True,
        enable_thinking=False     
    )

    inputs = tokenizer(text, return_tensors = "pt").to("cuda")
    return len(inputs["input_ids"][0])

# %%
# Check token lengths
lens = []

for data in tqdm(dataset):
    length = get_text_len(data["chunk"])

    lens.append({"chunk": data["chunk"], "length": length})


df = pd.DataFrame.from_dict(lens)

df
# Out:
# 100%|██████████| 18914/18914 [00:44<00:00, 428.65it/s]
#                                                    chunk  length
# 0      THE CAVE OF ELEPHANTA.\n [Illustration: A view...     749
# 1      “The whole excavation consists of three princi...     731
# 2      But let us look a little further at the prophe...     711
# 3      “_Poiet_. I hope we shall have another good da...     677
# 4      “_Orn_. No such thing. The storm is their elem...     722
# ...                                                  ...     ...
# 18909  _Cæsar_, 125, 236.\n Camorra, the, 109.\n Capa...    1155
# 18910  Darwin, 224.\n Daumer, Dr, 72.\n Decision, the...    1302
# 18911  Habit, of prompt obedience, 20;\n in physical ...    1340
# 18912  Padua, the Arena Chapel, 132.\n Parents, the e...    1421
# 18913  Sadler, Professor, 221.\n Saviour, our, 145.\n...    1299
#
# [18914 rows x 2 columns]

# %%
df = df[df["length"] <= 1000]
df
# Out:
#                                                    chunk  length
# 0      THE CAVE OF ELEPHANTA.\n [Illustration: A view...     749
# 1      “The whole excavation consists of three princi...     731
# 2      But let us look a little further at the prophe...     711
# 3      “_Poiet_. I hope we shall have another good da...     677
# 4      “_Orn_. No such thing. The storm is their elem...     722
# ...                                                  ...     ...
# 18904  LESSON.\n_Passage chosen_: LE CORBEAU.\n“Augus...     936
# 18905  MAP QUESTIONS.\nFrom the _Geographical Readers...     774
# 18906  LESSON.\n_Step 1._—Get the pupils to describe ...     795
# 18907  OBJECTS.\n1. To give the girls some idea of co...     770
# 18908  LESSON.\n_Step 1._—Ask the girls what is meant...     735
#
# [18405 rows x 2 columns]

# %%
cleaned_dataset = [{"chunk": chunk} for chunk in df["chunk"].to_list()]
random.Random(42).shuffle(cleaned_dataset)  # reproducible shuffle

n_total = len(cleaned_dataset)

# 80:10:10 split
n_train = int(0.8 * n_total)
n_eval  = int(0.1 * n_total)
n_test  = n_total - n_train - n_eval  # ensures all items are used

train_dataset = cleaned_dataset[:n_train]
eval_dataset  = cleaned_dataset[n_train:n_train + n_eval]
test_dataset  = cleaned_dataset[n_train + n_eval:]

print(len(train_dataset), len(eval_dataset), len(test_dataset))
print(f"Total: {n_total}")
# Out:
# 14724 1840 1841
# Total: 18405

# %%
test = [{"role":"system", "content": system_prompt}, {"role":"user", "content": train_dataset[0]["chunk"]}]

# %%
train_dataset[0]
# Out:
# {'chunk': 'III. Shall conclude with an exhortation to all of you, high and\n low, rich and poor, one with another, to have a regard to your\n behaviour at all times, but more especially, my dear brethren,\n on this solemn occasion.\nI. My brethren, I am to shew when your celebration of this festival is\nnot of the right kind.\nAnd _First_, you do not celebrate this aright, when you spend most of\nyour time in cards, dice, or gaming of any sort.\nThis is a season, for which there is no more allowance for wasting\nof your precious time in those unlawful entertainments, than any\nother. Persons are apt to flatter themselves that they are free and at\nliberty to spend whole evenings now at cards, at dice, or any diversion\nwhatsoever, to pass away, as they call it, a tedious evening. They\ncan do any thing now to pass away that, which is hastening as fast as\nthought: time is always upon the wing; it is no sooner present but it\nis past, and no sooner come but it is gone. And have we so much to do,\nand so little time to do it in, and yet complain of time lying heavy\nupon our hands? Have we not the devil and the beast to get out of our\nsouls? Are not our natures to be changed, our corruptions to be subdued,\nour wills to be brought over to GOD, our hard hearts to be softened,\nall old things to be done away, and all things to become new in our\nsouls? Is there not all this to be done? And yet we have too much time\nupon our hands! It is well, that instead of having too much time, it\nbe not found that we have got too little, when we come to die: then\nwe shall wish, my brethren, that we had made more account of our time,\nthat we had improved it for the glory of GOD, and the welfare of our\nimmortal souls.\nGood GOD! how amazing is the consideration, that many can go to church\nin the morning, and take the Sacrament, and come home and spend the\nafternoon and evening in cards: Is this, my brethren, discerning the\nLORD’s body? Is this taking the sacrament according to its institution?\nIs not this a pollution thereof, and making the blood of the covenant\nan unholy thing.'}

# %%
# Test model

text = tokenizer.apply_chat_template(
    test,
    tokenize = False,
    add_generation_prompt=True,
    enable_thinking=False     
)

inputs = tokenizer(text, return_tensors = "pt").to("cuda")

outputs = model.generate(
    **inputs,
    temperature = 0.7,
    top_p=0.8,
    top_k=20,
    min_p=0.0,
    max_new_tokens = 2048,
    streamer = TextStreamer(tokenizer, skip_prompt = True),
)
# Out:
# III. 皆に、高下、貧富を問わず、常に行為に注意を払い、特にこの聖なる日においては、戒めを受けてほしい。
# I. 兄弟たち、この祭りを正しく祝うべきではないときがある。まず、カード、サイコロ、いかなる不正な娯楽に時間を費やすのは、この時期に特に許されない。時間は常に飛んでいる。過ぎれば過ぎるほど、我々は仕事に多く、時間に少なすぎるのに、時間の重さを嘆くのか？魂の中の悪魔と野性をどうにかし、性質を変えるべきである。心を神に従わせ、硬い心を柔らかくし、すべての旧いものを捨て、新しいものに変えなければならない。しかし、我々は時間の余剰をもつのか？死に際して、時間の不足を知れば、悔い改め、神の栄光と魂の幸福のために時間を活かすべきだと願うだろう。天に、朝に教会に参列し、聖餐を受けても、昼間から晩にカードを楽しむ者がいる。これは、主の体を敬うのか？聖餐の本来の意味に従っているのか？これは聖約の血を汚し、不聖なる行為である。<|im_end|>

# %%
output = outputs[:, inputs["input_ids"].shape[1]:]

output_text = tokenizer.decode(output[0], skip_special_tokens=True)

output_text
# Out:
# 'III. 皆に、高下、貧富を問わず、常に行為に注意を払い、特にこの聖なる日においては、戒めを受けてほしい。  \nI. 兄弟たち、この祭りを正しく祝うべきではないときがある。まず、カード、サイコロ、いかなる不正な娯楽に時間を費やすのは、この時期に特に許されない。時間は常に飛んでいる。過ぎれば過ぎるほど、我々は仕事に多く、時間に少なすぎるのに、時間の重さを嘆くのか？魂の中の悪魔と野性をどうにかし、性質を変えるべきである。心を神に従わせ、硬い心を柔らかくし、すべての旧いものを捨て、新しいものに変えなければならない。しかし、我々は時間の余剰をもつのか？死に際して、時間の不足を知れば、悔い改め、神の栄光と魂の幸福のために時間を活かすべきだと願うだろう。天に、朝に教会に参列し、聖餐を受けても、昼間から晩にカードを楽しむ者がいる。これは、主の体を敬うのか？聖餐の本来の意味に従っているのか？これは聖約の血を汚し、不聖なる行為である。'

# %%
chunk_tokens = tokenizer(train_dataset[0]["chunk"])

tokenizer.decode(chunk_tokens["input_ids"], skip_special_tokens=True)
# Out:
# 'III. Shall conclude with an exhortation to all of you, high and\n low, rich and poor, one with another, to have a regard to your\n behaviour at all times, but more especially, my dear brethren,\n on this solemn occasion.\nI. My brethren, I am to shew when your celebration of this festival is\nnot of the right kind.\nAnd _First_, you do not celebrate this aright, when you spend most of\nyour time in cards, dice, or gaming of any sort.\nThis is a season, for which there is no more allowance for wasting\nof your precious time in those unlawful entertainments, than any\nother. Persons are apt to flatter themselves that they are free and at\nliberty to spend whole evenings now at cards, at dice, or any diversion\nwhatsoever, to pass away, as they call it, a tedious evening. They\ncan do any thing now to pass away that, which is hastening as fast as\nthought: time is always upon the wing; it is no sooner present but it\nis past, and no sooner come but it is gone. And have we so much to do,\nand so little time to do it in, and yet complain of time lying heavy\nupon our hands? Have we not the devil and the beast to get out of our\nsouls? Are not our natures to be changed, our corruptions to be subdued,\nour wills to be brought over to GOD, our hard hearts to be softened,\nall old things to be done away, and all things to become new in our\nsouls? Is there not all this to be done? And yet we have too much time\nupon our hands! It is well, that instead of having too much time, it\nbe not found that we have got too little, when we come to die: then\nwe shall wish, my brethren, that we had made more account of our time,\nthat we had improved it for the glory of GOD, and the welfare of our\nimmortal souls.\nGood GOD! how amazing is the consideration, that many can go to church\nin the morning, and take the Sacrament, and come home and spend the\nafternoon and evening in cards: Is this, my brethren, discerning the\nLORD’s body? Is this taking the sacrament according to its institution?\nIs not this a pollution thereof, and making the blood of the covenant\nan unholy thing.'

# %%
print(f"""The number of tokens in the input was {len(chunk_tokens["input_ids"])}""")
print(f"The number of tokens in the output was {len(output[0])-1}")
# Out:
# The number of tokens in the input was 512
# The number of tokens in the output was 296

# %%
# Train Dataset
trainset = [
    {"prompt": sample["chunk"]} for sample in train_dataset
]
trainset = Dataset.from_list(trainset)
trainset = trainset.map(lambda x: {
    "prompt" : [
        {"role": "system", "content": system_prompt},
        {"role": "user",   "content": x["prompt"]},
    ],
})
# Out:
# Map:   0%|          | 0/14724 [00:00<?, ? examples/s]

# %%
# Eval Dataset
evalset = [
    {"prompt": sample["chunk"]} for sample in eval_dataset[:20]
]
evalset = Dataset.from_list(evalset)
evalset = evalset.map(lambda x: {
    "prompt" : [
        {"role": "system", "content": system_prompt},
        {"role": "user",   "content": x["prompt"]},
    ],
})
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]

# %%
_original_apply_chat_template = tokenizer.apply_chat_template

def wrapped_apply_chat_template(conversation, *args, **kwargs):
    # Always inject enable_thinking=False
    kwargs['enable_thinking'] = False
    return _original_apply_chat_template(conversation, *args, **kwargs)

tokenizer.apply_chat_template = wrapped_apply_chat_template

tokenizer.apply_chat_template
# Out:
# <function __main__.wrapped_apply_chat_template(conversation, *args, **kwargs)>

# %% [markdown]
# # GRPO

# %% [markdown]
# ## Reconstruction

# %%
decoding_system_prompt = (
    "You are given compressed text generated by another model, which may be in a different language or a mix of different languages.\n"
    "Your goal is to accurately reconstruct the original uncompressed text IN ENGLISH.\n"
    "Do NOT include any reasoning or commentary — only output the reconstructed text in ENGLISH."
)

# %%
def recontruct_input(output):

    messages = [
        {"role": "system", "content": decoding_system_prompt},
        {"role": "user", "content": output}
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize = False,
        add_generation_prompt=True,
        enable_thinking=False     
    )

    inputs = tokenizer(text, return_tensors = "pt").to("cuda")

    resp = model.generate(
        **inputs,
        temperature = 0.7,
        top_p=0.8,
        top_k=20,
        min_p=0.0,
        max_new_tokens = 2048,
    )

    reconstructed_tokens = resp[:, inputs["input_ids"].shape[1]:]

    reconstructed_text = tokenizer.decode(reconstructed_tokens[0], skip_special_tokens=True)

    return reconstructed_text

# %% [markdown]
# ## Reward formulation

# %%
def get_num_tokens(text: str):
    chunk_tokens = tokenizer(text)
    return float(len(chunk_tokens["input_ids"]))



def get_bleu_score(original, reconstructed):
    hypothesis = reconstructed.split()
    reference = original.split()
    
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
    return BLEUscore - 1



def get_bertscore(original, reconstructed, model_type='bert-base-uncased'):

    P, R, F1 = bert_score([reconstructed], [original], model_type=model_type, verbose=False)

    return float(F1.mean()) - 1

 

def get_length_reward(original, compressed):
    len_original = get_num_tokens(original)
    len_compressed = get_num_tokens(compressed)
    
    # r = (len_original - len_compressed) * (1/len_original)
    r = np.clip((len_original - len_compressed) * (2/len_original), -1, 1)

    return r
    

def get_multilingual_diversity_reward(text, target_langs=None):
    words = re.findall(r'\b\w+\b', text)
    if not words:
        return 0.0
    langs = []
    for w in words:
        lang, _ = langid.classify(w)
        if target_langs is None or lang in target_langs:
            langs.append(lang)
    if not langs:
        return 0.0

    counts = np.array(list(Counter(langs).values()), dtype=float)
    probs = counts / counts.sum()

    # Use normalized entropy as a continuous diversity measure
    entropy = -np.sum(probs * np.log(probs + 1e-9))
    max_entropy = np.log(len(counts))
    reward = entropy / max_entropy if max_entropy > 0 else 0.0

    return float(reward)


def calculate_rewards(prompts, completions, alpha: float = 0.90, **kwargs):
    chunk = prompts[0][-1]["content"]
    responses = [completion[0]["content"] for completion in completions]

    rewards = []

    for response in responses:
        # First calculate r_len
        r_len = get_length_reward(chunk, response)

        # Now reconstruct input
        reconstructed = recontruct_input(response)

        # r_bleu = get_bleu_score(chunk ,reconstructed)

        r_bert = get_bertscore(chunk, reconstructed)

        r_multi = get_multilingual_diversity_reward(response)
        
        r_final = alpha * r_bert + (1 - alpha) * r_len + 0.2 * r_multi

        rewards.append(r_final)

    return rewards

# %% [markdown]
# ## Train the model

# %%
max_prompt_length = 1024
max_completion_length = max_seq_length - max_prompt_length

from vllm import SamplingParams
vllm_sampling_params = SamplingParams(
    min_p = 0,
    top_p = 0.8,
    top_k = 20,
    seed = 3407,
    stop = [tokenizer.eos_token],
    include_stop_str_in_output = True,
)

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    vllm_sampling_params = vllm_sampling_params,
    temperature = 0.7,
    learning_rate = 1e-5,
    weight_decay = 0.001,
    warmup_ratio = 0.1,
    lr_scheduler_type = "linear",
    optim = "adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 4,
    gradient_accumulation_steps = 2, # Increase to 4 for smoother training
    num_generations = 4, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_completion_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 500,
    save_steps = 10,
    report_to = "none", # Can use Weights & Biases
    output_dir = "/hpc/home/bfa6/work/github/yapper/results/test6/output",

    # For optional training + evaluation
    # fp16_full_eval = True,
    # per_device_eval_batch_size = 4,
    # eval_accumulation_steps = 1,
    # eval_strategy = "steps",
    # eval_steps = 300,
)

# %%
# For optional training + evaluation
# new_dataset = dataset.train_test_split(test_size = 0.01)

trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        calculate_rewards
    ],
    args = training_args,
    train_dataset = trainset,

    # For optional training + evaluation
    # train_dataset = trainset,
    # eval_dataset = evalset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 14,724 | Num Epochs = 1 | Total steps = 500
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 16,515,072 of 4,038,983,168 (0.41% trained)
# WARNING 11-20 21:04:02 [processor.py:215] vLLM has deprecated support for supporting different tokenizers for different LoRAs. By default, vLLM uses base model's tokenizer. If you are using a LoRA with its own tokenizer, consider specifying `--tokenizer [lora_path]` to use the LoRA tokenizer.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='18' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 18/500 39:34 < 19:52:24, 0.01 it/s, Epoch 0.00/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>reward</th>
#       <th>reward_std</th>
#       <th>completions / mean_length</th>
#       <th>completions / min_length</th>
#       <th>completions / max_length</th>
#       <th>completions / clipped_ratio</th>
#       <th>completions / mean_terminated_length</th>
#       <th>completions / min_terminated_length</th>
#       <th>completions / max_terminated_length</th>
#       <th>sampling / sampling_logp_difference / mean</th>
#       <th>sampling / sampling_logp_difference / max</th>
#       <th>sampling / importance_sampling_ratio / min</th>
#       <th>sampling / importance_sampling_ratio / mean</th>
#       <th>sampling / importance_sampling_ratio / max</th>
#       <th>kl</th>
#       <th>rewards / calculate_rewards / mean</th>
#       <th>rewards / calculate_rewards / std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.006600</td>
#       <td>-0.311910</td>
#       <td>0.029985</td>
#       <td>432.000000</td>
#       <td>337.000000</td>
#       <td>647.000000</td>
#       <td>0.000000</td>
#       <td>432.000000</td>
#       <td>337.000000</td>
#       <td>647.000000</td>
#       <td>0.092951</td>
#       <td>2.927329</td>
#       <td>0.000000</td>
#       <td>0.700867</td>
#       <td>1.875926</td>
#       <td>0.001872</td>
#       <td>-0.311910</td>
#       <td>0.104236</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000700</td>
#       <td>-0.268872</td>
#       <td>0.045842</td>
#       <td>314.875000</td>
#       <td>176.000000</td>
#       <td>503.000000</td>
#       <td>0.000000</td>
#       <td>314.875000</td>
#       <td>176.000000</td>
#       <td>503.000000</td>
#       <td>0.041233</td>
#       <td>2.186025</td>
#       <td>0.000000</td>
#       <td>0.514297</td>
#       <td>1.575404</td>
#       <td>0.001836</td>
#       <td>-0.268872</td>
#       <td>0.079470</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003700</td>
#       <td>-0.274179</td>
#       <td>0.052014</td>
#       <td>402.125000</td>
#       <td>354.000000</td>
#       <td>455.000000</td>
#       <td>0.000000</td>
#       <td>402.125000</td>
#       <td>354.000000</td>
#       <td>455.000000</td>
#       <td>0.083150</td>
#       <td>2.171771</td>
#       <td>0.000000</td>
#       <td>0.868547</td>
#       <td>1.895300</td>
#       <td>0.001604</td>
#       <td>-0.274179</td>
#       <td>0.131047</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001700</td>
#       <td>-0.329778</td>
#       <td>0.014219</td>
#       <td>341.750000</td>
#       <td>212.000000</td>
#       <td>536.000000</td>
#       <td>0.000000</td>
#       <td>341.750000</td>
#       <td>212.000000</td>
#       <td>536.000000</td>
#       <td>0.067394</td>
#       <td>2.076464</td>
#       <td>0.000000</td>
#       <td>0.653697</td>
#       <td>1.736477</td>
#       <td>0.002396</td>
#       <td>-0.329778</td>
#       <td>0.101402</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>-0.006900</td>
#       <td>-0.348343</td>
#       <td>0.042373</td>
#       <td>330.250000</td>
#       <td>211.000000</td>
#       <td>449.000000</td>
#       <td>0.000000</td>
#       <td>330.250000</td>
#       <td>211.000000</td>
#       <td>449.000000</td>
#       <td>0.075879</td>
#       <td>1.975814</td>
#       <td>0.000000</td>
#       <td>0.667313</td>
#       <td>1.944001</td>
#       <td>0.002102</td>
#       <td>-0.348343</td>
#       <td>0.074937</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>-0.290656</td>
#       <td>0.010507</td>
#       <td>405.625000</td>
#       <td>308.000000</td>
#       <td>488.000000</td>
#       <td>0.000000</td>
#       <td>405.625000</td>
#       <td>308.000000</td>
#       <td>488.000000</td>
#       <td>0.086099</td>
#       <td>2.767700</td>
#       <td>0.000000</td>
#       <td>0.832929</td>
#       <td>1.802516</td>
#       <td>0.001569</td>
#       <td>-0.290656</td>
#       <td>0.057116</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>-0.001500</td>
#       <td>-0.330605</td>
#       <td>0.024899</td>
#       <td>378.875000</td>
#       <td>215.000000</td>
#       <td>456.000000</td>
#       <td>0.000000</td>
#       <td>378.875000</td>
#       <td>215.000000</td>
#       <td>456.000000</td>
#       <td>0.085050</td>
#       <td>2.161323</td>
#       <td>0.000000</td>
#       <td>0.779628</td>
#       <td>1.861824</td>
#       <td>0.001652</td>
#       <td>-0.330605</td>
#       <td>0.092794</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001900</td>
#       <td>-0.235362</td>
#       <td>0.009839</td>
#       <td>340.750000</td>
#       <td>249.000000</td>
#       <td>404.000000</td>
#       <td>0.000000</td>
#       <td>340.750000</td>
#       <td>249.000000</td>
#       <td>404.000000</td>
#       <td>0.102535</td>
#       <td>2.797299</td>
#       <td>0.000000</td>
#       <td>0.812600</td>
#       <td>1.988775</td>
#       <td>0.002007</td>
#       <td>-0.235362</td>
#       <td>0.092604</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.002300</td>
#       <td>-0.321615</td>
#       <td>0.030618</td>
#       <td>301.500000</td>
#       <td>179.000000</td>
#       <td>469.000000</td>
#       <td>0.000000</td>
#       <td>301.500000</td>
#       <td>179.000000</td>
#       <td>469.000000</td>
#       <td>0.086482</td>
#       <td>2.440881</td>
#       <td>0.000000</td>
#       <td>0.649390</td>
#       <td>1.981236</td>
#       <td>0.002168</td>
#       <td>-0.321615</td>
#       <td>0.110341</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000700</td>
#       <td>-0.266536</td>
#       <td>0.029892</td>
#       <td>445.000000</td>
#       <td>277.000000</td>
#       <td>542.000000</td>
#       <td>0.000000</td>
#       <td>445.000000</td>
#       <td>277.000000</td>
#       <td>542.000000</td>
#       <td>0.086352</td>
#       <td>2.002004</td>
#       <td>0.000000</td>
#       <td>0.754883</td>
#       <td>1.932724</td>
#       <td>0.001962</td>
#       <td>-0.266536</td>
#       <td>0.098355</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.007000</td>
#       <td>-0.302073</td>
#       <td>0.027916</td>
#       <td>596.625000</td>
#       <td>461.000000</td>
#       <td>794.000000</td>
#       <td>0.000000</td>
#       <td>596.625000</td>
#       <td>461.000000</td>
#       <td>794.000000</td>
#       <td>0.085689</td>
#       <td>2.601518</td>
#       <td>0.000000</td>
#       <td>0.794233</td>
#       <td>1.937085</td>
#       <td>0.001756</td>
#       <td>-0.302073</td>
#       <td>0.073732</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.012900</td>
#       <td>-0.276128</td>
#       <td>0.022947</td>
#       <td>250.000000</td>
#       <td>195.000000</td>
#       <td>324.000000</td>
#       <td>0.000000</td>
#       <td>250.000000</td>
#       <td>195.000000</td>
#       <td>324.000000</td>
#       <td>0.100452</td>
#       <td>2.212226</td>
#       <td>0.000000</td>
#       <td>0.794291</td>
#       <td>1.849491</td>
#       <td>0.001988</td>
#       <td>-0.276128</td>
#       <td>0.100464</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>-0.004700</td>
#       <td>-0.303119</td>
#       <td>0.015440</td>
#       <td>359.750000</td>
#       <td>195.000000</td>
#       <td>492.000000</td>
#       <td>0.000000</td>
#       <td>359.750000</td>
#       <td>195.000000</td>
#       <td>492.000000</td>
#       <td>0.088128</td>
#       <td>1.946144</td>
#       <td>0.000000</td>
#       <td>0.744016</td>
#       <td>1.727916</td>
#       <td>0.001782</td>
#       <td>-0.303119</td>
#       <td>0.102029</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.000900</td>
#       <td>-0.247506</td>
#       <td>0.032951</td>
#       <td>280.250000</td>
#       <td>207.000000</td>
#       <td>363.000000</td>
#       <td>0.000000</td>
#       <td>280.250000</td>
#       <td>207.000000</td>
#       <td>363.000000</td>
#       <td>0.089103</td>
#       <td>1.712167</td>
#       <td>0.000000</td>
#       <td>0.781068</td>
#       <td>1.826241</td>
#       <td>0.001804</td>
#       <td>-0.247506</td>
#       <td>0.117517</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.004000</td>
#       <td>-0.350341</td>
#       <td>0.023105</td>
#       <td>469.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 17
#       1 # For optional training + evaluation
#       2 # new_dataset = dataset.train_test_split(test_size = 0.01)
#       4 trainer = GRPOTrainer(
#       5     model = model,
#       6     processing_class = tokenizer,
#    (...)
#      15     # eval_dataset = evalset,
#      16 )
# ---> 17 trainer.train()
#
# File /work/bfa6/github/yapper/notebooks/unsloth_compiled_cache/UnslothGRPOTrainer.py:54, in prepare_for_training_mode.<locals>.wrapper(self, *args, **kwargs)
#      52 if hasattr(self, 'model') and hasattr(self.model, "for_training"):
#      53     self.model.for_training()
# ---> 54 output = f(self, *args, **kwargs)
#      55 # Return inference mode
#      56 if hasattr(self, 'model') and hasattr(self.model, "for_inference"):
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/transformers/trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File <string>:325, in _fast_inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#
# File <string>:34, in _unsloth_training_step(self, model, inputs, num_items_in_batch)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/trl/extras/profiling.py:98, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#      95 @functools.wraps(func)
#      96 def wrapper(self, *args, **kwargs):
#      97     with profiling_context(self, func.__name__):
# ---> 98         return func(self, *args, **kwargs)
#
# File /work/bfa6/github/yapper/notebooks/unsloth_compiled_cache/UnslothGRPOTrainer.py:2215, in _UnslothGRPOTrainer._prepare_inputs(self, generation_batch)
#    2212 generate_every = self.args.steps_per_generation * self.num_iterations
#    2213 if self._step % generate_every == 0 or self._buffered_inputs is None:
#    2214     # self._buffered_inputs=None can occur when resuming from a checkpoint
# -> 2215     generation_batch = self._generate_and_score_completions(generation_batch)
#    2216     generation_batch = split_pixel_values_by_grid(generation_batch)
#    2218     try: generation_batch = shuffle_sequence_dict(generation_batch)
#
# File /work/bfa6/github/yapper/notebooks/unsloth_compiled_cache/UnslothGRPOTrainer.py:2670, in _UnslothGRPOTrainer._generate_and_score_completions(self, inputs)
#    2665     completions = completions_text
#    2667 # Calculate rewards for each reward function. rewards_per_func aggregates rewards across all processes. This is
#    2668 # important because rewards will be normalized per group, and completions are distributed. We will later slice
#    2669 # rewards_per_func to extract each process's subset.
# -> 2670 rewards_per_func = self._calculate_rewards(inputs, original_prompts, completions, completion_ids_list)
#    2672 # Apply weights to each reward function's output and sum
#    2673 rewards = (rewards_per_func * self.reward_weights.to(device).unsqueeze(0)).nansum(dim=1)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/trl/extras/profiling.py:98, in profiling_decorator.<locals>.wrapper(self, *args, **kwargs)
#      95 @functools.wraps(func)
#      96 def wrapper(self, *args, **kwargs):
#      97     with profiling_context(self, func.__name__):
# ---> 98         return func(self, *args, **kwargs)
#
# File /work/bfa6/github/yapper/notebooks/unsloth_compiled_cache/UnslothGRPOTrainer.py:2260, in _UnslothGRPOTrainer._calculate_rewards(self, inputs, prompts, completions, completion_ids_list)
#    2258         rewards_per_func[:, i] = reward_func(**reward_inputs).logits[:, 0]  # Shape (B*G,)
#    2259 else:
# -> 2260     output_reward_func = reward_func(
#    2261         prompts=prompts, completions=completions, completion_ids=completion_ids_list, **reward_kwargs
#    2262     )
#    2263     # Convert None values to NaN
#    2264     output_reward_func = [reward if reward is not None else torch.nan for reward in output_reward_func]
#
# Cell In[35], line 68, in calculate_rewards(prompts, completions, alpha, **kwargs)
#      65 r_len = get_length_reward(chunk, response)
#      67 # Now reconstruct input
# ---> 68 reconstructed = recontruct_input(response)
#      70 # r_bleu = get_bleu_score(chunk ,reconstructed)
#      72 r_bert = get_bertscore(chunk, reconstructed)
#
# Cell In[34], line 17, in recontruct_input(output)
#       8 text = tokenizer.apply_chat_template(
#       9     messages,
#      10     tokenize = False,
#      11     add_generation_prompt=True,
#      12     enable_thinking=False
#      13 )
#      15 inputs = tokenizer(text, return_tensors = "pt").to("cuda")
# ---> 17 resp = model.generate(
#      18     **inputs,
#      19     temperature = 0.7,
#      20     top_p=0.8,
#      21     top_k=20,
#      22     min_p=0.0,
#      23     max_new_tokens = 2048,
#      24 )
#      26 reconstructed_tokens = resp[:, inputs["input_ids"].shape[1]:]
#      28 reconstructed_text = tokenizer.decode(reconstructed_tokens[0], skip_special_tokens=True)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/peft/peft_model.py:1973, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1971     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1972         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1973         outputs = self.base_model.generate(*args, **kwargs)
#    1974 else:
#    1975     outputs = self.base_model.generate(**kwargs)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/unsloth/models/llama.py:2032, in unsloth_fast_generate(self, *args, **kwargs)
#    2027 # Mixed precision autocast
#    2028 with (
#    2029     torch.inference_mode(),
#    2030     torch.autocast(device_type = DEVICE_TYPE_TORCH, dtype = dtype),
#    2031 ):
# -> 2032     output = self._old_generate(*args, **kwargs)
#    2034 # Return accelerate back
#    2035 # if accelerate_new_send_to_device is not None:
#    2036 #     accelerate.utils.operations.send_to_device = accelerate_old_send_to_device
#    2037 # pass
#    2039 FastLlamaModel.for_training(self)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:2539, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2528     return GenerationMixin.generate(
#    2529         self,
#    2530         inputs,
#    (...)
#    2534         **kwargs,
#    2535     )
#    2537 elif generation_mode in (GenerationMode.SAMPLE, GenerationMode.GREEDY_SEARCH):
#    2538     # 11. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2539     result = self._sample(
#    2540         input_ids,
#    2541         logits_processor=prepared_logits_processor,
#    2542         stopping_criteria=prepared_stopping_criteria,
#    2543         generation_config=generation_config,
#    2544         synced_gpus=synced_gpus,
#    2545         streamer=streamer,
#    2546         **model_kwargs,
#    2547     )
#    2549 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2550     # 11. run beam sample
#    2551     result = self._beam_search(
#    2552         input_ids,
#    2553         logits_processor=prepared_logits_processor,
#    (...)
#    2557         **model_kwargs,
#    2558     )
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/transformers/generation/utils.py:2870, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2868     is_prefill = False
#    2869 else:
# -> 2870     outputs = model_forward(**model_inputs, return_dict=True)
#    2872 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    2873 model_kwargs = self._update_model_kwargs_for_generation(
#    2874     outputs,
#    2875     model_kwargs,
#    2876     is_encoder_decoder=self.config.is_encoder_decoder,
#    2877 )
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/unsloth/models/llama.py:1296, in CausalLM_fast_forward.<locals>._CausalLM_fast_forward(self, input_ids, causal_mask, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, num_logits_to_keep, logits_to_keep, *args, **kwargs)
#    1277 def _CausalLM_fast_forward(
#    1278     self,
#    1279     input_ids: torch.LongTensor = None,
#    (...)
#    1293     **kwargs,
#    1294 ) -> Union[Tuple, CausalLMOutputWithPast]:
#    1295     if past_key_values is not None:
# -> 1296         outputs = fast_forward_inference(
#    1297             self,
#    1298             input_ids,
#    1299             past_key_values,
#    1300             position_ids = position_ids,
#    1301             attention_mask = attention_mask,
#    1302         )
#    1303     else:
#    1304         causal_mask = (
#    1305             xformers.attn_bias.LowerTriangularMask() if HAS_XFORMERS else None
#    1306         )
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/unsloth/models/llama.py:1238, in _LlamaModel_fast_forward_inference.<locals>.LlamaModel_fast_forward_inference_custom(self, input_ids, past_key_values, position_ids, attention_mask)
#    1235 X += residual
#    1237 residual.copy_(X)  # residual = X
# -> 1238 X = fast_rms_layernorm_inference(
#    1239     decoder_layer.post_attention_layernorm,
#    1240     X,
#    1241     XX = XX,
#    1242     XX2 = XX2,
#    1243     variance = variance,
#    1244 )
#    1245 X = mlp_fast_forward_inference(
#    1246     decoder_layer.mlp,
#    1247     X,
#    1248     temp_gate = temp_gates[device_index],
#    1249     temp_up = temp_ups[device_index],
#    1250 )
#    1251 X += residual
#
# File ~/work/github/yapper/.venv/lib/python3.10/site-packages/unsloth/models/llama.py:485, in fast_rms_layernorm_inference(self, X, XX, XX2, variance)
#     483     torch_mean(torch_square(XX, out = XX2), -1, keepdim = True, out = variance)
#     484 variance += self.variance_epsilon
# --> 485 XX *= variance.rsqrt_()
#     487 if XX is None:
#     488     X = XX.to(old_dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # Load and Test Model

# %%
max_seq_length = 3096 # Can increase for longer reasoning traces
lora_rank = 8 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen3-0.6B",
    cache_dir="/hpc/home/bfa6/work/llms/.cache",
    max_seq_length = max_seq_length,
    load_in_4bit = False, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
    # force_download=True
)
# Out:
# INFO 11-15 12:57:10 [vllm_utils.py:700] Unsloth: Patching vLLM v1 graph capture
# ==((====))==  Unsloth 2025.11.2: Fast Qwen3 patching. Transformers: 4.56.2. vLLM: 0.11.0.
#    \\   /|    NVIDIA RTX 6000 Ada Generation. Num GPUs = 1. Max memory: 47.372 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu128. CUDA: 8.9. CUDA Toolkit: 12.8. Triton: 3.4.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.32.post1. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/Qwen3-0.6B with actual GPU utilization = 23.87%
# Unsloth: Your GPU has CUDA compute capability 8.9 with VRAM = 47.37 GB.
# Unsloth: Using conservativeness = 1.0. Chunked prefill tokens = 3096. Num Sequences = 224.
# Unsloth: vLLM's KV Cache can use up to 10.33 GB. Also swap space = 6 GB.
# Unsloth: Not an error, but `device` is not supported in vLLM. Skipping.
# INFO 11-15 12:57:12 [utils.py:233] non-default args: {'dtype': torch.bfloat16, 'seed': 0, 'max_model_len': 3096, 'enable_prefix_caching': True, 'swap_space': 6, 'gpu_memory_utilization': 0.23866632824105866, 'max_num_batched_tokens': 2048, 'max_num_seqs': 224, 'max_logprobs': 0, 'disable_log_stats': True, 'enable_lora': True, 'max_lora_rank': 32, 'enable_chunked_prefill': True, 'compilation_config': {"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":null,"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":25,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":null,"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":null,"local_cache_dir":null}, 'model': 'unsloth/Qwen3-0.6B'}
# INFO 11-15 12:57:13 [model.py:547] Resolved architecture: Qwen3ForCausalLM
# INFO 11-15 12:57:13 [model.py:1510] Using max model len 3096
# INFO 11-15 12:57:13 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=2048.
# WARNING 11-15 12:57:13 [lora.py:92] `lora_extra_vocab_size` is deprecated and will be removed in v0.12.0. Additional vocabulary support for LoRA adapters is being phased out.
# INFO 11-15 12:57:13 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='unsloth/Qwen3-0.6B', speculative_config=None, tokenizer='unsloth/Qwen3-0.6B', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.bfloat16, max_seq_len=3096, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=unsloth/Qwen3-0.6B, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"inductor","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention","vllm.sparse_attn_indexer"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"epilogue_fusion":true,"max_autotune":false,"shape_padding":true,"trace.enabled":false,"triton.cudagraphs":true,"debug":false,"dce":true,"memory_planning":true,"coordinate_descent_tuning":false,"trace.graph_diagram":false,"compile_threads":25,"group_fusion":true,"disable_progress":false,"verbose_progress":true,"triton.multi_kernel":0,"triton.use_block_ptr":true,"triton.enable_persistent_tma_matmul":true,"triton.autotune_at_compile_time":false,"triton.cooperative_reductions":false,"cuda.compile_opt_level":"-O2","cuda.enable_cuda_lto":true,"combo_kernels":false,"benchmark_combo_kernel":true,"combo_kernel_foreach_dynamic_shapes":true,"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":448,"local_cache_dir":null}
# INFO 11-15 12:57:14 [gpu_model_runner.py:2602] Starting to load model unsloth/Qwen3-0.6B...
# INFO 11-15 12:57:15 [gpu_model_runner.py:2634] Loading model from scratch...
# INFO 11-15 12:57:15 [weight_utils.py:392] Using model weights format ['*.safetensors']
# INFO 11-15 12:57:15 [weight_utils.py:450] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# INFO 11-15 12:57:15 [default_loader.py:267] Loading weights took 0.28 seconds
# INFO 11-15 12:57:17 [gpu_model_runner.py:2653] Model loading took 1.1551 GiB and 0.539210 seconds
# INFO 11-15 12:57:25 [backends.py:548] Using cache directory: /hpc/home/bfa6/.cache/vllm/torch_compile_cache/40e0a6e6d2/rank_0_0/backbone for vLLM's torch.compile
# INFO 11-15 12:57:25 [backends.py:559] Dynamo bytecode transform time: 7.44 s
# Unsloth: Compiling kernels: 100%|██████████| 7/7 [00:02<00:00,  2.45it/s, triton_poi_fused_view_6]
# INFO 11-15 12:57:31 [backends.py:197] Cache the graph for dynamic shape for later use
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:02<00:00,  4.50it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 98.59it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 99.04it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 124.95it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 134.33it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 128.56it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 131.00it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 138.17it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 108.16it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 139.27it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 112.59it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 141.75it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 90.49it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 127.14it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 116.74it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 161.12it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 172.90it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 122.73it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 109.02it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 147.24it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 142.39it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 136.77it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 123.17it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 127.52it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 124.90it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 110.28it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 11/11 [00:00<00:00, 144.77it/s, triton_poi_fused_view_10]
# Unsloth: Compiling kernels: 100%|██████████| 5/5 [00:00<00:00, 11.70it/s, triton_per_fused__to_copy_add_mean_mul_pow_rsqrt_4]
# INFO 11-15 12:58:06 [backends.py:218] Compiling a graph for dynamic shape takes 40.41 s
# INFO 11-15 12:58:29 [monitor.py:34] torch.compile takes 47.85 s in total
# INFO 11-15 12:58:31 [gpu_worker.py:298] Available KV cache memory: 8.92 GiB
# INFO 11-15 12:58:32 [kv_cache_utils.py:1087] GPU KV cache size: 83,552 tokens
# INFO 11-15 12:58:32 [kv_cache_utils.py:1091] Maximum concurrency for 3,096 tokens per request: 26.92x
# INFO 11-15 12:58:32 [vllm_utils.py:705] Unsloth: Running patched vLLM v1 `capture_model`.
# INFO 11-15 12:58:32 [vllm_utils.py:705] Unsloth: Running patched vLLM v1 `capture_model`.
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 59/59 [00:05<00:00, 10.94it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 31/31 [00:02<00:00, 11.41it/s]
# INFO 11-15 12:58:40 [gpu_model_runner.py:3480] Graph capturing finished in 8 secs, took 0.79 GiB
# INFO 11-15 12:58:40 [vllm_utils.py:712] Unsloth: Patched vLLM v1 graph capture finished in 8 secs.
# INFO 11-15 12:58:40 [vllm_utils.py:712] Unsloth: Patched vLLM v1 graph capture finished in 8 secs.
# INFO 11-15 12:58:41 [core.py:210] init engine (profile, create kv cache, warmup model) took 84.63 seconds
# INFO 11-15 12:58:42 [llm.py:306] Supported_tasks: ('generate',)
# Unsloth: Just some info: will skip parsing ['post_layernorm', 'layer_norm1', 'norm2', 'pre_feedforward_layernorm', 'attention_norm', 'norm', 'layer_norm2', 'k_norm', 'q_norm', 'norm1', 'post_attention_layernorm', 'post_feedforward_layernorm', 'input_layernorm', 'ffn_norm']
# Performing substitution for additional_keys=set()
# Unsloth: Just some info: will skip parsing ['post_layernorm', 'cross_attn_post_attention_layernorm', 'layer_norm1', 'norm2', 'pre_feedforward_layernorm', 'attention_norm', 'norm', 'layer_norm2', 'k_norm', 'q_norm', 'norm1', 'post_attention_layernorm', 'post_feedforward_layernorm', 'input_layernorm', 'cross_attn_input_layernorm', 'ffn_norm']

# %%
from peft import PeftModel
model = PeftModel.from_pretrained(model, "/hpc/home/bfa6/work/github/yapper/results/experiment_0/test0/save")

# %%
FastLanguageModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): Qwen3ForCausalLM(
#       (model): Qwen3Model(
#         (embed_tokens): Embedding(151936, 1024, padding_idx=151654)
#         (layers): ModuleList(
#           (0-27): 28 x Qwen3DecoderLayer(
#             (self_attn): Qwen3Attention(
#               (q_proj): lora.Linear(
#                 (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1024, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=2048, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear(
#                 (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1024, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear(
#                 (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1024, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear(
#                 (base_layer): Linear(in_features=2048, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=2048, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): Qwen3MLP(
#               (gate_proj): lora.Linear(
#                 (base_layer): Linear(in_features=1024, out_features=3072, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1024, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=3072, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear(
#                 (base_layer): Linear(in_features=1024, out_features=3072, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=1024, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=3072, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear(
#                 (base_layer): Linear(in_features=3072, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=3072, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#             (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#           )
#         )
#         (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=1024, out_features=151936, bias=False)
#     )
#   )
# )

# %%
def compress_text(text, temperature=0.7, max_tokens=2048):
    """Compress a given text using the trained model."""
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": text}
    ]
    
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    outputs = model.generate(
        **inputs,
        temperature=temperature,
        top_p=0.8,
        top_k=20,
        min_p=0.0,
        max_new_tokens=max_tokens,
        streamer=TextStreamer(tokenizer, skip_prompt=True),
    )
    
    output_tokens = outputs[:, inputs["input_ids"].shape[1]:]
    compressed = tokenizer.decode(output_tokens[0], skip_special_tokens=True)
    
    return compressed, len(inputs["input_ids"][0]), len(output_tokens[0])

# %%
test_sample = test_dataset[0]["chunk"]
test_sample
# Out:
# 'The status of the church in its relation to youth to-day is generally\ndisappointing. Unless it is improved, the kingdom will become a victim\nof race suicide. In certain larger lines, the world seems to be\nadvancing; in the simpler matters of personal ideals and moral\nstandards, many people think it to be losing ground.\n\nThe origin of our problem is threefold. It comes, first, from a growing\nreign of carnality in the world—the seeking of wealth and pleasure at any\ncost. It comes, secondly, from the surrender of erstwhile righteous as\nwell as indifferent homes to the notion that, since one is young but once,\nhe should be encouraged to spoil the only youth he is to have. It comes,\nthirdly, from a condition in social institutions and community life which\nmakes it difficult for one to live the better life without severing the\nsocial ties that bind him to others.\n\nYoung people cannot pass through the public schools of the average city\nwithout making a choice between being worldly and being wall flowers. It\neven seems that a young man cannot go through a great war for humanity\nwithout having the tobacco habit forced upon him as a part of a great\npropaganda for commercial purposes. Boys and girls can hardly attend a\nsocial function without seeing indecent attire and being invited to\nparticipate in things which deteriorate faith and ideals.\n\nOur equipment for meeting the situation is generally inadequate. We have\nplenty of organization, but it is too general, too miscellaneous, and too\nmuch interested in funds and reports. We have too many young people’s\norganizations and too little life in any of them. This is a general\ntrouble with Methodism. We would do better with one tenth of our present\nmachinery and nine times more use of that one tenth.\n\nOur program should probably cover the following points, all of which are\nold and simple: _(1) A warm spiritual life and a high personal ideal for\nall_. There are no exceptions for age or youth in the standards of the\nkingdom. _(2) An emphasis on family faith and practice, with a revival of\nproper parental authority_. If the children must rule, let the parents at\nleast retain veto power in the interest of right living. _(3) A program\nof community reconstruction_ which will ultimately make schools and other\npublic institutions as respectful of the ideals of evangelical Christians\nas they now are of those of Jews and Roman Catholics. _(4) Simple but\neffective organization for the recognition of the young people of the\nchurch as a normal social group_ and for their development along the lines\nindicated in the growth of Jesus—wisdom, stature, favor with God, and\nfavor with man. There is no better program of training than that which\nincludes mind, body, religious instinct, and social relationships.'

# %%
# Test on a sample from test set
test_sample = test_dataset[1]["chunk"]

print("="*80)
print("ORIGINAL TEXT:")
print("="*80)
print(test_sample)
print("\n" + "="*80)
print("COMPRESSED OUTPUT:")
print("="*80)

compressed, input_len, output_len = compress_text(test_sample)

print("\n" + "="*80)
print(f"Original tokens: {input_len}")
print(f"Compressed tokens: {output_len}")
print(f"Compression ratio: {output_len/input_len:.2%}")
print(f"Token reduction: {input_len - output_len} tokens ({(1 - output_len/input_len)*100:.1f}% reduction)")
# Out:
# ================================================================================
# ORIGINAL TEXT:
# ================================================================================
# RASPBERRY PARFAIT
#
#   1 pint of cream,
#   1 pint of raspberries,
#     Sugar.
#
# Whip a pint of cream until very stiff, and sweeten with powdered
# sugar slightly. Cook the raspberries until broken, which should not
# take more than five or six minutes; press out all the juice and pulp
# possible, and reboil with three-fourths as much sugar as juice. Allow
# this to cool. Spread whipped cream in a mold, and pour some of the
# raspberry syrup over, and add more cream, and so fill the mold. Unless
# one prefers, then the syrup and whipped cream may be lightly mixed
# before packing in the mold. Pack in ice and salt and allow to stand for
# several hours.
#
#
# MAPLE BISQUE
#
#   2 eggs,
#   ½ pint of cream,
#   ½ cupful of maple syrup,
#     Vanilla.
#
# Beat the yolks of the eggs until very light, add the maple syrup
# slowly, and heat over a slow fire, stirring constantly until it reaches
# the boiling point. Boil for one minute only; remove from the fire,
# strain and cool.
#
# Beat the cream until firm and add to the stiffly beaten whites of the
# eggs. Pour the syrup mixture over this slowly, beating constantly; add
# the vanilla. Pour into a mold, pack and freeze.
#
#
# PEACH MELBA
#
#   1 pint of heavy cream,
#   1 pint of milk,
#   1 cupful of sugar,
#   1 tablespoonful of gelatine,
#   ½ teaspoonful of vanilla,
#   1 can of large peaches or ½ dozen selected peaches.
#
# Heat the milk and sugar, until the sugar is thoroughly dissolved;
# dissolve gelatine in a little cold milk and add to the heated milk and
# sugar.
#
# Allow this to cool, add the cream whipped stiffly, flavor and pour into
# the freezer. Freeze until the crank turns very hard; remove the dasher,
# repack and allow to stand for two hours.
#
# When ready to serve, place a half peach on the bottom of a long stemmed
# glass, fill with the cream, put the other half of the peach on top and
# top with raspberry syrup, then the whipped cream.
#
#
# SAUCE.—To one cupful of raspberry jam add one cupful of boiling water
# sweetened a bit; boil for five minutes, strain, chill and use.
#
#
# PEACH DELIGHT
#
#   2 cupfuls of water,
#   ¾ cupful of honey,
#   1 teaspoonful of gelatine,
#   1 cupful of peach pulp,
#   1 lemon,
#   1 orange,
#   1 cupful of cream, whipped.
#
# Bring the water and honey to the boiling point and continue to cook
# for twenty minutes. Add the gelatine which should have been soaked and
# dissolved in a little cold water; strain and allow to cool.
#
# When cold add the peach pulp, orange pulp, orange juice and the juice
# of half a lemon. Turn into a freezer and freeze slowly. Serve in
# attractive glasses, topped with whipped cream.
#
# ================================================================================
# COMPRESSED OUTPUT:
# ================================================================================
# <|im_end|>
#
# ================================================================================
# Original tokens: 731
# Compressed tokens: 1
# Compression ratio: 0.14%
# Token reduction: 730 tokens (99.9% reduction)

# %%
def reconstruct_text(compressed_text, max_tokens=784):
    """Reconstruct original text from compressed version."""
    messages = [
        {"role": "system", "content": decoding_system_prompt},
        {"role": "user", "content": compressed_text}
    ]
    
    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
        enable_thinking=False
    )
    
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    
    outputs = model.generate(
        **inputs,
        temperature=0.7,
        top_p=0.8,
        top_k=20,
        min_p=0.0,
        max_new_tokens=max_tokens,
    )
    
    output_tokens = outputs[:, inputs["input_ids"].shape[1]:]
    reconstructed = tokenizer.decode(output_tokens[0], skip_special_tokens=True)
    
    return reconstructed

# %%
# Reconstruct from compressed
print("="*80)
print("RECONSTRUCTED TEXT:")
print("="*80)

reconstructed = reconstruct_text(compressed)
print(reconstructed)

print("\n" + "="*80)
print("QUALITY METRICS:")
print("="*80)

# Calculate BLEU score
bleu = get_bleu_score(test_sample, reconstructed)
print(f"BLEU Score: {bleu + 1:.4f}")  # Add 1 back since we subtracted it in reward

# Calculate compression reward
compression_reward = get_length_reward(test_sample, compressed)
print(f"Compression Reward: {compression_reward:.4f}")

# Calculate final reward (as used in training)
alpha = 0.8
final_reward = alpha * bleu + (1 - alpha) * compression_reward
print(f"Final Reward (alpha={alpha}): {final_reward:.4f}")
# Out:
# ================================================================================
# RECONSTRUCTED TEXT:
# ================================================================================
#
#
# ================================================================================
# QUALITY METRICS:
# ================================================================================
# BLEU Score: 0.0000
# Compression Reward: 1.0000
# Final Reward (alpha=0.8): -0.6000

# %%
def evaluate_test_set(test_data, num_samples=100):
    """Evaluate model on multiple test samples."""
    results = []
    
    for i, sample in enumerate(tqdm(test_data[:num_samples], desc="Evaluating")):
        original = sample["chunk"]
        
        # Compress
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": original}
        ]
        prompt = tokenizer.apply_chat_template(
            messages, tokenize=False, add_generation_prompt=True, enable_thinking=False
        )
        inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
        
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                temperature=0.7,
                top_p=0.8,
                top_k=20,
                max_new_tokens=2048,
            )
        
        output_tokens = outputs[:, inputs["input_ids"].shape[1]:]
        compressed = tokenizer.decode(output_tokens[0], skip_special_tokens=True)
        
        # Reconstruct
        reconstructed = reconstruct_text(compressed)
        
        # Calculate metrics
        orig_len = get_num_tokens(original)
        comp_len = get_num_tokens(compressed)
        bleu = get_bleu_score(original, reconstructed)
        comp_ratio = comp_len / orig_len
        
        results.append({
            "original_tokens": orig_len,
            "compressed_tokens": comp_len,
            "compression_ratio": comp_ratio,
            "bleu_score": bleu + 1,  # Add back the -1
            "sample_idx": i
        })
    
    return pd.DataFrame(results)

# %%
eval_results = evaluate_test_set(eval_dataset, num_samples=100)
# Out:
# Evaluating:  94%|█████████▍| 94/100 [00:18<00:01,  5.20it/s]Unsloth: Input IDs of shape torch.Size([1, 2094]) with length 2094 > the model's max sequence length of 2048.
# We shall truncate it ourselves. It's imperative if you correct this issue first.
# Evaluating: 100%|██████████| 100/100 [00:19<00:00,  5.15it/s]

# %%
print("="*80)
print("TEST SET EVALUATION SUMMARY")
print("="*80)
print(f"\nNumber of samples: {len(eval_results)}")
print(f"\nAverage compression ratio: {eval_results['compression_ratio'].mean():.2%}")
print(f"Median compression ratio: {eval_results['compression_ratio'].median():.2%}")
print(f"Std compression ratio: {eval_results['compression_ratio'].std():.4f}")
print(f"\nAverage BLEU score: {eval_results['bleu_score'].mean():.4f}")
print(f"Median BLEU score: {eval_results['bleu_score'].median():.4f}")
print(f"Std BLEU score: {eval_results['bleu_score'].std():.4f}")
print(f"\nAverage token reduction: {(eval_results['original_tokens'] - eval_results['compressed_tokens']).mean():.1f} tokens")
print(f"Total tokens saved: {(eval_results['original_tokens'] - eval_results['compressed_tokens']).sum():.0f} tokens")
# Out:
# ================================================================================
# TEST SET EVALUATION SUMMARY
# ================================================================================
#
# Number of samples: 100
#
# Average compression ratio: 0.00%
# Median compression ratio: 0.00%
# Std compression ratio: 0.0000
#
# Average BLEU score: 0.0000
# Median BLEU score: 0.0000
# Std BLEU score: 0.0000
#
# Average token reduction: 679.9 tokens
# Total tokens saved: 67985 tokens

# %%
# Create visualizations
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Compression ratio distribution
axes[0, 0].hist(eval_results['compression_ratio'], bins=30, edgecolor='black', alpha=0.7)
axes[0, 0].set_xlabel('Compression Ratio')
axes[0, 0].set_ylabel('Frequency')
axes[0, 0].set_title('Distribution of Compression Ratios')
axes[0, 0].axvline(eval_results['compression_ratio'].mean(), color='red', linestyle='--', 
                   label=f'Mean: {eval_results["compression_ratio"].mean():.2%}')
axes[0, 0].legend()

# BLEU score distribution
axes[0, 1].hist(eval_results['bleu_score'], bins=30, edgecolor='black', alpha=0.7, color='green')
axes[0, 1].set_xlabel('BLEU Score')
axes[0, 1].set_ylabel('Frequency')
axes[0, 1].set_title('Distribution of BLEU Scores')
axes[0, 1].axvline(eval_results['bleu_score'].mean(), color='red', linestyle='--',
                   label=f'Mean: {eval_results["bleu_score"].mean():.4f}')
axes[0, 1].legend()

# Compression vs BLEU scatter
axes[1, 0].scatter(eval_results['compression_ratio'], eval_results['bleu_score'], alpha=0.5)
axes[1, 0].set_xlabel('Compression Ratio')
axes[1, 0].set_ylabel('BLEU Score')
axes[1, 0].set_title('Compression Ratio vs BLEU Score')

# Token reduction
axes[1, 1].hist(eval_results['original_tokens'] - eval_results['compressed_tokens'], 
                bins=30, edgecolor='black', alpha=0.7, color='orange')
axes[1, 1].set_xlabel('Tokens Saved')
axes[1, 1].set_ylabel('Frequency')
axes[1, 1].set_title('Distribution of Token Savings')

plt.tight_layout()
plt.savefig('/hpc/home/bfa6/work/github/yapper/results/test2/evaluation_results.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Save detailed results
eval_results.to_csv('/hpc/home/bfa6/work/github/yapper/results/test/test_results.csv', index=False)
print("Results saved to test_results.csv")

# %%
# Find best and worst samples
best_idx = eval_results.sort_values('bleu_score', ascending=False).iloc[0]['sample_idx']
worst_idx = eval_results.sort_values('bleu_score', ascending=True).iloc[0]['sample_idx']

print("="*80)
print("BEST COMPRESSION (Highest BLEU)")
print("="*80)
print(f"\nOriginal:\n{test_dataset[int(best_idx)]['chunk'][:500]}...")
compressed_best, _, _ = compress_text(test_dataset[int(best_idx)]['chunk'])
print(f"\nCompressed:\n{compressed_best[:500]}...")
print(f"\nBLEU: {eval_results.iloc[int(best_idx)]['bleu_score']:.4f}")
print(f"Compression: {eval_results.iloc[int(best_idx)]['compression_ratio']:.2%}")

print("\n" + "="*80)
print("WORST COMPRESSION (Lowest BLEU)")
print("="*80)
print(f"\nOriginal:\n{test_dataset[int(worst_idx)]['chunk'][:500]}...")
compressed_worst, _, _ = compress_text(test_dataset[int(worst_idx)]['chunk'])
print(f"\nCompressed:\n{compressed_worst[:500]}...")
print(f"\nBLEU: {eval_results.iloc[int(worst_idx)]['bleu_score']:.4f}")
print(f"Compression: {eval_results.iloc[int(worst_idx)]['compression_ratio']:.2%}")
# Out:
# ================================================================================
# BEST COMPRESSION (Highest BLEU)
# ================================================================================
#
# Original:
# The status of the church in its relation to youth to-day is generally
# disappointing. Unless it is improved, the kingdom will become a victim
# of race suicide. In certain larger lines, the world seems to be
# advancing; in the simpler matters of personal ideals and moral
# standards, many people think it to be losing ground.
#
# The origin of our problem is threefold. It comes, first, from a growing
# reign of carnality in the world—the seeking of wealth and pleasure at any
# cost. It comes, secondly, from t...
# <|im_end|>
#
# Compressed:
# ...
#
# BLEU: 0.0000
# Compression: 0.00%
#
# ================================================================================
# WORST COMPRESSION (Lowest BLEU)
# ================================================================================
#
# Original:
# The status of the church in its relation to youth to-day is generally
# disappointing. Unless it is improved, the kingdom will become a victim
# of race suicide. In certain larger lines, the world seems to be
# advancing; in the simpler matters of personal ideals and moral
# standards, many people think it to be losing ground.
#
# The origin of our problem is threefold. It comes, first, from a growing
# reign of carnality in the world—the seeking of wealth and pleasure at any
# cost. It comes, secondly, from t...
# <|im_end|>
#
# Compressed:
# ...
#
# BLEU: 0.0000
# Compression: 0.00%
